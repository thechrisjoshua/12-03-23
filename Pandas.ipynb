# %%
import pandas as pd
df= pd.read_csv("returns1020.csv")
df.head(50)
# Out:
#          Date   GSPCRet   FTSERet
# 0    1/1/2010  0.000000  0.000000
# 1    1/4/2010 -0.008912  0.000000
# 2    1/5/2010  0.014419  0.016147
# 3    1/6/2010  0.002693  0.004036
# 4    1/7/2010  0.000493  0.001358
# 5    1/8/2010  0.003740 -0.000597
# 6   1/11/2010  0.004770  0.001357
# 7   1/12/2010 -0.001876  0.000705
# 8   1/13/2010 -0.005683 -0.007114
# 9   1/14/2010  0.007359 -0.004583
# 10  1/15/2010  0.001781  0.004513
# 11  1/18/2010  0.000000 -0.007784
# 12  1/19/2010 -0.010185  0.007149
# 13  1/20/2010  0.010493  0.003404
# 14  1/21/2010 -0.008075 -0.016742
# 15  1/22/2010 -0.020366 -0.015809
# 16  1/25/2010 -0.020699 -0.006017
# 17  1/26/2010  0.003112 -0.008052
# 18  1/27/2010 -0.003523  0.003156
# 19  1/28/2010  0.004570 -0.011257
# 20  1/29/2010 -0.008497 -0.013761
# 21   2/1/2010 -0.012615  0.008318
# 22   2/2/2010  0.015048  0.011352
# 23   2/3/2010  0.009743  0.006841
# 24   2/4/2010 -0.003107 -0.005697
# 25   2/5/2010 -0.030194 -0.021682
# ...
